# %%
from bs4 import BeautifulSoup

# %%
from selenium import webdriver

# %%
import time

# %%
#You need to have Chrome driver downloaded in your computer
#http://chromedriver.chromium.org/

#You need to have driver corresponding to your Google Chrome browser or update browser
from selenium.webdriver.common.by import By

# %%
#this generates USNs from 1 to 330 
#If your branch is different then you can change the branch code such as BEC,BCV etc
usns=[]
for i in range(1,330):
    if i<=9:
        usn='01FE20BEC00'+str(i)
    elif i>=10 and i<=99:
        usn='01FE20BEC0'+str(i)
    else:
        usn='01FE20BEC'+str(i)
    usns.append(usn)
#For ECE INTEGRATED
for i in range(1,100):
    if i<=9:
        usn='01FE20BEI00'+str(i)
    elif i>=10 and i<=99:
        usn='01FE20BEI0'+str(i)
    else:
        usn='01FE20BEI'+str(i)
    usns.append(usn)
#For Diploma students
for i in range(1,36):
    if i<=9:
        usn='01FE21BEC40'+str(i)
    elif i>=10 and i<=99:
        usn='01FE21BEC4'+str(i)
    usns.append(usn)

# %% [markdown]
# ### Run the cell below and wait until Google Chrome opens

# %%
url="https://eresults.kletech.ac.in/index.php"

#This is the path name of chrome driver on my PC
driver = webdriver.Chrome("/Users/anandsagar/Downloads/chromedriver_mac_arm64 (2)/chromedriver")

driver.get(url)
driver.maximize_window()
# Out:
# /var/folders/v6/4dy5mw7n4mv20vx6d9n95qs80000gn/T/ipykernel_40946/1041103949.py:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("/Users/anandsagar/Downloads/chromedriver_mac_arm64 (2)/chromedriver")

# %% [markdown]
# ### When website Opens then change the captcha below and run the cell
#
# ### My college website has a glitch that its captcha doesn't change if we navigate back on the website

# %%
#put the captcha as shown in website and run this cell
captcha="PGMRJ" #this was the current captcha when I was using

# %%
file=open('result5_ECE_sgpa.csv','a') #This is the file in which I am storing Name and SGPA

# %%
#For each USN I am scrapping the details
for username in usns:
    driver.find_element(by=By.NAME,value="usn").send_keys(username)
    driver.find_element(by=By.NAME,value="osolCatchaTxt").send_keys(captcha)

    # driver.find_element_by_formaction("index.php?option=com_examresult&task=getResult").click()
    driver.find_element(By.XPATH, '//button[text()="Result"]').click()
    
    #I am handling the exception because there are certain USNs whose result is not declared or some USNs don't exist
    try:
        #This //div..... may change depending on what you are trying to scrap
        name=driver.find_element(By.XPATH,'//div[contains(@class,"uk-card uk-card-body stu-data stu-data1")]')
        print(name.text) #optional
        
    except:
        print("Error in name")
    
    try:
        sgpa=driver.find_element(By.XPATH,'//div[contains(@class,"uk-card uk-card-default uk-card-body credits-sec3")]')
        print(sgpa.text[5:]) #Since the extracted data has SGPA as suffix but we need to store only numerical part
        file.write('\n'+(name.text)+','+(sgpa.text[5:]))
    except:
        print("Error in sgpa")
        
    driver.back() #navigating back by clicking back button

    driver.find_element(by=By.NAME,value="usn").clear() #clearing the already filled detail
    driver.find_element(by=By.NAME,value="osolCatchaTxt").clear() #Clearing the CAPTCHA field as it will be Entered aagain
# Out:
# NIRMITH EMMANUEL PUNEET
# 8.20
# VIKAS B NAVALGUND
# 2.76
# ANOKA FERNANDES
# 8.05
# NIDHI A DARAK
# 8.98
# SAMARTH RAJARAM URANAKAR
# 8.12
# CHETANA SHIVANAND RAJAPUT
# 7.07
# PRATIKSHA NAIK
# 8.07
# Error in name
# Error in sgpa
# DAIVARATH B N
# 7.36
# MANJUNATH JAVALI
# 8.05
# SRINIDHI
# 7.80
# ARVIND M MORBAD
# 6.60
# MADUR HIREMATH
# 5.36
# Error in name
# Error in sgpa
# YASHRAJ S TATUSKAR
# 5.54
# NAGARAJ SHASHIKUMAR HIREMATH
# 5.05
# Error in name
# Error in sgpa
# AVINASH V V
# 8.74
# ANOOP AMARESH HANCHATE
# 6.47
# RAJAT BADARIPRASAD KULKARNI
# 8.09
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# SHIVAM HANDIGOL
# 7.12
# AIZAZAHAMAD SURANAGI
# 8.38
# PRAJWAL PANCHAKSHARAIAH GARWADMATH
# 7.12
# KHUSHI TALLI
# 8.80
# SUHAS M
# 5.60
# AARYA K H
# 8.80
# Error in name
# Error in sgpa
# RAHUL R GUNADALMATH
# 5.92
# SAHANA SANJAY KASHIGAR
# 7.16
# SINCHANA PRALHADA MASKERI
# 8.54
# SAHANA RAJESH HIREMATH
# 8.78
# TUSHAR GUPTA
# 7.36
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# MANOJ PM
# 8.54
# KUSHAL BAHUBALI KOKATNUR
# 8.23
# Error in name
# Error in sgpa
# HRISHIKESH HABBU
# 7.03
# SRUSHTI SHETTAR
# 8.54
# VINAY HEGDE
# 7.18
# REVANTH GIRISH KANAVI
# 2.47
# PRITHVI P PATIL
# 7.75
# SHREYAS MAGAJIKONDI
# 7.98
# SHOBITH BANKAPUR
# 7.94
# CHINMAY G KOTUR
# 8.94
# LAXMI HANUMANT KOLKAR
# 7.25
# MAHEK JAIN
# 9.43
# PRAJWAL GANGADHAR SHETTY KODIHALLI
# 9.45
# ABHAY JOSHI
# 8.18
# SHREYA P KHANADALE
# 6.92
# Error in name
# Error in sgpa
# SNEHA B PATIL
# 8.94
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# GURUDATTA J BHAT
# 8.43
# Error in name
# Error in sgpa
# PRASHANTH HULLIKUPPI
# 8.25
# HIMANSHU ASHOK KUMAR PAVECHA
# 9.07
# SHREYAS MAHESH WANDKAR
# 8.63
# Error in name
# Error in sgpa
# MANJUNATH SHIVAPPA KHOT
# 7.89
# ANKUSHPRASAD L PATHAK
# 8.00
# AKHILESH SHASHIKANTH KAMBLE
# 7.83
# MOHAMMED FARAZ Z K
# 7.32
# ABHIDNY MALLIKARJUN MATTIHAL
# 7.27
# MANOJGOUDA KUBERAGOUDA RABBANAGOUDRA
# 8.14
# JAYARAM LAMANI
# 2.00
# ASHWINI JITURI
# 8.45
# PREETI R MADALLI
# 7.98
# RASHMI PRAKASH CHAVAN
# 2.47
# PRUTHVIRAJ S T
# 4.87
# SHIFA THAREEN MD AYUB JAMADAR
# 9.14
# TRUPTI PARASHURAM BANKADAMANI
# 7.76
# SANJANA RAJESH MISKIN
# 8.65
# YALLALING MAHADEV KURUBAGATTI
# 8.72
# ANIRUDDH VINAY JAHAGIRDAR
# 8.85
# ROHIT SHASHIKANT KADEMANI
# 8.63
# Error in name
# Error in sgpa
# PRAMATH K
# 7.12
# Error in name
# Error in sgpa
# MURARI G
# 8.56
# RHEA S MANE
# 7.75
# S YALAGURESH
# 6.60
# DARSHAN S KATAGIHALLIMATH
# 8.89
# Error in name
# Error in sgpa
# MOHAMMADSAMIULLA BILAGI
# 8.72
# AKASH KAMBLE
# 7.23
# DIVYA HEGDE
# 9.07
# REVATI KARALATTI
# 8.63
# KAVYA HEGDE
# 9.03
# SHEELA SIDDARAM KAPASE
# 8.69
# SANSKRUTI KANAVALLI
# 7.89
# Error in name
# Error in sgpa
# SOUMYA H J
# 9.18
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# ANUP A KOTUR
# 4.25
# VAISHANAVI UMESH SHETTI
# 9.00
# ANAND DODDAMANI
# 8.52
# SUMIT PATIL
# 6.47
# TEJASHWINI S JAVALAGADDI
# 7.80
# VARSHA N SALI
# 7.87
# BASANGOUDA S PATIL
# 2.96
# LOHIT M KUDLANNAVAR
# 8.89
# Error in name
# Error in sgpa
# GIRIGOUD PATIL
# 6.87
# KOUSHIK GANESH GUNDU
# 7.32
# NITISH D KULKARNI
# 8.38
# Error in name
# Error in sgpa
# KEERTHI SUTAR
# 5.18
# ATHARV VIJAY PUROHIT
# 7.36
# D S SANJAYA
# 9.32
# BHUSHAN INAMDAR
# 9.00
# RAGHAVENDRA KALLUR
# 8.32
# VINAYKUMAR
# 8.74
# RAMYA S PATIL
# 9.03
# T MAITRI
# 9.00
# KARTHIK
# 7.94
# VINAY PRAKASH JANEWAD
# 8.07
# SANSKRUTI VEERAPPA SHIDDALINGAPPANAVAR
# 8.60
# NIKITA PATIL
# 9.03
# SAKSHI SHAYAM DESAI
# 8.74
# SHASHANK B GOLASANGI
# 8.78
# NUTHANKUMAR NARAYAN NAIK
# 8.67
# RASHMI PARUTAYYA GAVIMATH
# 8.45
# RUCHITH TILAVALLI
# 8.65
# SHIVANI S KALBURGI
# 8.87
# OMKAR BOLAKE
# 8.47
# ANUSHA SHANKAR BAGALI
# 8.60
# SUJATA SEETARAM VIJAPUR
# 7.52
# FARHEEN TANVIRAHMED DEHALVI
# 7.75
# PALLAVI DASHARATH MYAGERI
# 8.58
# D SHREYAS
# 7.75
# Error in name
# Error in sgpa
# PRAJWAL UDAY JAHAGIRDAR
# 8.49
# ABHISHEK ANNAPPA KUMBAR
# 7.49
# VEERESH NAGESHAPPA AKKI
# 8.60
# ANUSHA C S
# 8.74
# ROHAN RAMACHANDRA KULKARNI
# 7.05
# VINOD N PATIL
# 4.69
# SHAHEEN KHAN
# 8.69
# MAHESHKUMAR BASAVARAJ WADDATTI
# 7.14
# RAGAVENDRA VINAYAK JOSHI
# 7.00
# NIKHIL KUMAR S PAWAR
# 7.60
# VIVEK RAJENDRA GAONKAR
# 9.07
# ANANYA KHED
# 9.00
# PRABHANJAN SANTIKELUR
# 7.56
# ADITI P SARDESAI
# 9.00
# Error in name
# Error in sgpa
# PRUTHVI HANAMANT PUJAR
# 5.05
# CHETAN MAHESH WADDARKALL
# 9.00
# RADHIKA HORTI
# 9.12
# AKASH S UPASE
# 8.67
# GURUMURTHY V HEGDE
# 8.23
# AKSHAY RAWAL
# 7.98
# DIVYA VINAYAK NAIK
# 8.38
# KSHETRAPAL S BALIGAR
# 8.23
# RAJAT ANIL LAD
# 7.27
# BHOOMIKA MANJUNATH KIVADAR
# 8.67
# SAGAR TUGASHETTI
# 8.45
# Error in name
# Error in sgpa
# SAMPADA S KULKARNI
# 7.75
# R S SHRIGANESH
# 6.94
# KAMAT GURUPRASAD SANJAY
# 9.23
# Error in name
# Error in sgpa
# PRASHANT SHIVAYOGAYYA HAVERIMATH
# 8.00
# BHUVAN A KURAKUNDI
# 8.67
# VAISHNAVI SHRIDHAR BHAT
# 8.09
# FARDIN KHAN
# 8.98
# Error in name
# Error in sgpa
# RAMA BASAVAYYA GONDA
# 8.43
# SUHAS
# 8.63
# DISHA RAJU KEMBLE
# 7.52
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# AMOGH A BHARGAV
# 5.43
# TARUN S GOUDAR
# 8.96
# SHRAVAN HOSKOTI
# 7.12
# ROCHAN BACHARI
# 8.16
# HARSHA S HIREGOUDAR
# 8.05
# G S ANOOP
# 7.75
# MAHESH MIRJE
# 7.52
# SAKSHI ROKHADE
# 6.98
# RUTIKA P DHEKANE
# 8.20
# DARSHAN GIRISH NAYAK
# 7.63
# VINOD MALLAPPA THAKKANNAVAR
# 6.83
# RITUPARNA SHIVAYOGI BALI
# 5.69
# ABHISHEK KUDACHI
# 7.98
# VISHAL K KULKARNI
# 8.47
# SHIVAYOGI NAGARAJ RITTI
# 7.40
# ABHIJIT PRABHAKAR BHORE
# 7.45
# KEDAR VISHWANATH BIKKANNAVAR
# 8.14
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# YASIN MEERASAB ALAGUR
# 8.12
# PAVAN PRAKASH MYAGERIMATH
# 8.38
# CHINMAY AVINASH JAVALAGI
# 8.80
# MEDHA K M
# 8.65
# HARSHA SIDDALINGESH JANGAMANI
# 8.60
# NACHIKET SHRIKANT HEGDE
# 8.94
# ANIRUDDHA S HADAGALI
# 8.23
# RAJASHEKAR I GANIGER
# 6.75
# SAGAR KARAVEERAPPANAVAR
# 7.83
# SIDDARTH NAKATI
# 8.45
# ANJALI T
# 8.63
# SNEHA G HIREHOLI
# 9.14
# RAHUL RAKESH CHHEDA
# 9.14
# Error in name
# Error in sgpa
# AMRUTA A MEHARWADE
# 8.20
# NEYUSH MOHTA
# 8.56
# KIRAN SHIVAPRAKASH HANAMAGOUDAR
# 8.29
# SANJANA B BAGEWADI
# 8.94
# SHARAT M JAMADAR
# 8.18
# SINDHOOR MAHABHALESHWAR HEGDE
# 6.14
# PRAJWAL T P
# 7.58
# ALIYA S GAJENDRAGAD
# 6.78
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# ROHIT UPARI
# 8.98
# SHREYAS M MURAGODMATH
# 8.80
# SOUMYA GANGADHAR SAJJAN
# 7.87
# POORVA RUDRAPUR
# 8.32
# TEJAS MARIYAPPAGOUDAR
# 6.52
# VIJAYSHANKAR NAGARAJ WARAD
# 8.67
# VAISHNAVI VASUDEV PAI
# 8.45
# POOJA RAMAPPA YARADDI
# 7.76
# KIRAN SHASHIDHAR GANAPA
# 8.40
# SAHANA SHIVANAGOUDA D
# 8.80
# KUSUMA M
# 8.29
# SAKSHI HALBHAVI
# 8.32
# SARVESH S INAMDAR
# 7.75
# SIDDESHA N M
# 7.83
# BAKKESH V AMOGHIMATH
# 7.47
# KHUSHI H M
# 8.47
# SAHANA MALLIKARJUN KOULAPUR
# 8.45
# NITISH NARAGUND
# 8.45
# SHRAVAN KUMAR INCHURA
# 7.92
# Error in name
# Error in sgpa
# HARISH MAHANTHGOUDA GOUDAR
# 3.80
# SPANDANA SANTOSH BANDEKAR
# 7.75
# FIZA A PADAGAM
# 3.78
# MALLANAGOUDA
# 7.94
# SURAJ REDDY
# 7.63
# SHRIRAKSHA
# 8.45
# SHARADA NARAYAN PATTAR
# 8.05
# Error in name
# Error in sgpa
# SHWETA B KAMATAD
# 8.63
# SPOORTI M GUJJAL
# 8.60
# VIJAY G PATIL
# 5.20
# SAGAR JOSHI
# 8.67
# SHREYA S B
# 6.34
# Error in name
# Error in sgpa
# RASHMI PRABHULING KOPPAD
# 7.36
# SAURAV KUMAR
# 7.40
# Error in name
# Error in sgpa
# SAMEER N MURTUGUDDE
# 5.63
# Error in name
# Error in sgpa
# ALLABAKASH GULAMOHAMMED GHODESAWAR
# 8.09
# Error in name
# Error in sgpa
# JAMES SAMUEL MIRAJKAR
# 8.96
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# NIHARIKA K
# 8.85
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# RAJESHGOUDA B PATIL
# 6.54
# SNEHA KUMARI
# 7.05
# KHUSHI PRIYADARSHI
# 7.56
# Error in name
# Error in sgpa
# HARSHIT SHARMA
# 8.09
# MARIGOUDA YELAGOUDA PATIL
# 7.92
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# AKASHGOUDA PATIL
# 7.78
# GOURI SHARAD SIRIYANNAVAR
# 7.54
# SUSMITA DANDIN
# 7.49
# MIHIR R KALAKAMB
# 7.78
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# YASHAS MANJUNATH HITTALMAKKI
# 8.23
# PRANSHU KUMAR
# 6.74
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# SNEHA S ANCHEKAR
# 7.38
# Error in name
# Error in sgpa
# SWAROOP UMESH ADRASHYAPPANAMATH
# 8.40
# NARRA ALEKYA
# 7.96
# ANIRUDH
# 7.23
# Error in name
# Error in sgpa
# VIPUL S TELKAR
# 6.23
# Error in name
# Error in sgpa
# ANEESHSINGH BHATKHANDE
# 7.20
# SRINIVAS KAVYA
# 7.83
# ASHISH KUMAR SINGH
# 7.52
# SIDDARTH T AKKATANGERHAL
# 8.65
# PRERANA B HUBLI
# 8.49
# VASUNDHARA V BALIGAR
# 8.47
# KRISHNAREDDY HANAMAPPA MAHARADDI
# 8.54
# ABHISHEK N MULAMUTTAL
# 8.60
# ANUSHA CHANDRASHEKARAYYA GADDADEVARAMATH
# 5.72
# ASIF KHAN SALIMKHAN MUSAFIR
# 4.74
# AMITHA H P
# 4.74
# PREETI B SULE
# 4.63
# Error in name
# Error in sgpa
# SHRADDHA S DAYANNAVAR
# 8.60
# SWAROOP S JARTARGHAR
# 5.23
# PRATHAM NARAYAN SHANBHAG
# 7.29
# NIKHIL S KULKARNI
# 7.18
# SHREESH A JOSHI
# 7.75
# SAMYAKTH AJIT MALGATTI
# 6.16
# Error in name
# Error in sgpa
# M B VAMSHI KRISHNA
# 5.38
# VENKATAPAVANKUMAR THOTA
# 7.75
# Error in name
# Error in sgpa
# POORNIMA HIREMATH
# 7.20
# Error in name
# Error in sgpa
# RAHUL H HANUMAGATTI
# 7.56
# Error in name
# Error in sgpa
# SWAROOP V KUBASAD
# 8.85
# AKSHATA ASHOK MADIWALAR
# 6.89
# S CHANDU
# 6.20
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# KARTIK M HUNAGUND
# 6.94
# ADIL N JAMADAR
# 8.89
# NAMITA K MANJUNATH
# 8.20
# ASHWIN KUMAR ATMANAND GEDDIKERI
# 6.78
# VARUN KRISHNA SAVADATTI
# 7.98
# ANMOL BHOSALE
# 8.94
# Error in name
# Error in sgpa
# MOHAMMED KHALID MOHAMMED HASHAM MUJAHID
# 8.14
# PARINIKA R KATTI
# 8.09
# KUNAL SHET
# 4.69
# AJIT S CHITTARGI
# 8.32
# Error in name
# Error in sgpa
# ALMAS ABDUL KHUDDUS SHAIKH
# 8.85
# VIVEKANAND R KUMACHAGI
# 8.29
# KHUSHI DHARWAD
# 7.80
# RAJEEV MALLIGAWAD
# 8.34
# ABHAY RAMACHANDRA DESHPANDE
# 7.58
# SHRIRAKSHA CHANNALLI
# 8.58
# SNEHA SATISH SHET
# 7.63
# SUPREET S MATH
# 6.80
# SONIA SUNIL ANVEKAR
# 8.38
# BHAVANA
# 9.03
# ROHIT KULALI
# 5.74
# PRAFUL BASAVARAJ BHUTI
# 6.96
# Error in name
# Error in sgpa
# PRIYANKA R HUNGUND
# 8.12
# BASAVPRABHU MANJUNATH DASTIKOP
# 8.23
# ADITI R HIREMATH
# 7.45
# SAMARTH S DESHPANDE
# 8.32
# VARSHA S PATIL
# 8.92
# RAGHAVENDRA T MASTI
# 6.07
# MRUTHUNJAYA HIREMATH
# 7.96
# Error in name
# Error in sgpa
# ADARSH SURESH GANDOLKAR
# 7.58
# Error in name
# Error in sgpa
# SHREYA H SANKANNAVAR
# 7.27
# SPOORTI SAINATH REVANKAR
# 5.76
# NETRA BASAVARAJ HALAWAGAL
# 9.03
# SAHANA TUKARAM ANKAD
# 9.20
# NAUSHEEN ARA MOHAMMED KHAN
# 8.83
# SAGAR SIDDAPPA MULAGUND
# 9.07
# KEERTI INGALI
# 8.98
# SHIVALEELA JAGADEESH HANAGI
# 7.29
# SHASHANK V S
# 7.80
# POORNIMA SHIVAMURTHAYYA BENDIGERIMATH
# 8.43
# SANIYA ERAM
# 4.76
# AANCHAL G PAWAR
# 9.03
# PRUTHVIRAJ YARIKOPPA
# 8.29
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# RAMYASHRI RAJENDRAKUMAR RAGHAPPANAVAR
# 8.18
# DHRUVATEJA S K
# 6.80
# PRASAD P KALGUTKAR
# 7.40
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# ARYA ARUN SHIRALIKAR
# 8.07
# NAMRUTA AMARSINGH HAJERI
# 6.56
# MRITUNJAY MALLIKARJUN MARIGOUDAR
# 7.45
# CHIRAG VINAYAK BANKAPUR
# 8.07
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# SHEETAL LAMANI
# 7.51
# PAVAN GAJANAN NETRAKAR
# 8.46
# KARTIK M MALAGANAVAR
# 8.55
# LALITA J SATARADDI
# 8.51
# VAIDEHI SANTOSH HERKAL
# 8.67
# SHRIDEVI RAJASHEKHAR JAVALI
# 8.81
# SAKSHI PRASHANT HEBLIKAR
# 8.08
# USTAP N NARAGUND
# 7.50
# AFAAQAHAMED N JAMADAR
# 9.04
# KEERTI SURYAKANT RAYANNAVAR
# 2.93
# SHRIKANTH RAMAPPA BHAJANTRI
# 3.75
# SAHANA BASANAGOUDA SALMANI
# 9.04
# MAHAMADSHAHID MAHAMADUSMAN GANJIWALE
# 8.57
# RASHMI GANGADHARAYYA NADURMATH
# 8.22
# SWATI
# 8.18
# ABHISHEK VEERANNA SAJJANAR
# 8.08
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa

# %%
file.close() #closing the file
