# %%
from bs4 import BeautifulSoup

# %%
from selenium import webdriver

# %%
import time

# %%
#You need to have Chrome driver downloaded in your computer
#http://chromedriver.chromium.org/

#You need to have driver corresponding to your Google Chrome browser or update browser
from selenium.webdriver.common.by import By

# %%
#this generates USNs from 1 to 330 
#If your branch is different then you can change the branch code such as BEC,BCV etc
usns=[]
for i in range(1,330):
    if i<=9:
        usn='01FE20BCS00'+str(i)
    elif i>=10 and i<=99:
        usn='01FE20BCS0'+str(i)
    else:
        usn='01FE20BCS'+str(i)
    usns.append(usn)

# %% [markdown]
# ### Run the cell below and wait until Google Chrome opens

# %%
url="https://eresults.kletech.ac.in/"

#This is the path name of chrome driver on my PC
driver = webdriver.Chrome("/Users/anandsagar/Downloads/chromedriver")

driver.get(url)
driver.maximize_window()
# Out:
# <ipython-input-16-81d2de497bb8>:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("/Users/anandsagar/Downloads/chromedriver")

# %% [markdown]
# ### When website Opens then change the captcha below and run the cell
#
# ### My college website has a glitch that its captcha doesn't change if we navigate back on the website

# %%
#put the captcha as shown in website and run this cell
captcha="6P9T8" #this was the current captcha when I was using

# %%
file=open('result4_sgpa.csv','a') #This is the file in which I am storing Name and SGPA

# %%
#For each USN I am scrapping the details
for username in usns:
    driver.find_element(by=By.NAME,value="usn").send_keys(username)
    driver.find_element(by=By.NAME,value="osolCatchaTxt").send_keys(captcha)

    # driver.find_element_by_formaction("index.php?option=com_examresult&task=getResult").click()
    driver.find_element(By.XPATH, '//button[text()="Result"]').click()
    
    #I am handling the exception because there are certain USNs whose result is not declared or some USNs don't exist
    try:
        #This //div..... may change depending on what you are trying to scrap
        name=driver.find_element(By.XPATH,'//div[contains(@class,"uk-card uk-card-body stu-data stu-data1")]')
        print(name.text) #optional
        
    except:
        print("Error in name")
    
    try:
        sgpa=driver.find_element(By.XPATH,'//div[contains(@class,"uk-card uk-card-default uk-card-body credits-sec3")]')
        print(sgpa.text[5:]) #Since the extracted data has SGPA as suffix but we need to store only numerical part
        file.write('\n'+(name.text)+','+(sgpa.text[5:]))
    except:
        print("Error in sgpa")
        
    driver.back() #navigating back by clicking back button

    driver.find_element(by=By.NAME,value="usn").clear() #clearing the already filled detail
    driver.find_element(by=By.NAME,value="osolCatchaTxt").clear() #Clearing the CAPTCHA field as it will be Entered aagain
# Out:
# ASHRITA ANAND GAONKAR
# 3.49
# SOUMYA KOTRESH KATAGIHALLI
# 8.18
# ADITYA DILIP JADHAV
# 3.05
# PRERANA SATYANARAYANA MURTHY MALAGI
# 7.90
# AKSHATA PARAMESH BADNI
# 7.05
# NEHA PATIL
# 8.09
# LOHIT VINAYAK GANGOLLI
# 4.15
# KONKATHI RITHIN KUMAR
# 1.79
# RANJITA PRASHANT HEGDE
# 7.75
# SRISHTI ANIL KADAM
# 7.64
# ULHAS S KALASA
# 7.75
# PRAVEEN VISHWA KULLI
# 7.75
# NIKHITA BALAJI NADAKARNI
# 4.88
# SANDEEP SADANAND HALKATTI
# 8.24
# SAHANA G AIDNAL
# 3.73
# SRUSHTI PRAKASH NAYAK
# 5.28
# ANANYA M PATIL
# 6.64
# CHIRAG SANDEEP METGUD
# 6.81
# SHREYA B DEVAGIRI
# 9.15
# AJAY BASAVARAJ POLIS GOWDAR
# 0.52
# AISHWARYA GANIGER
# 4.60
# ASHIKA IRAPPA KOLAKAR
# 6.52
# GANESHDARSHAN MALAGI
# 7.81
# ANEESH SUDHEENDRA VAIDYA
# 4.52
# SUSHIR RAMESH METI
# 7.13
# S SAMHITH KUMAR
# 6.62
# RANJEETA BASAVARAJ ANGADI
# 3.24
# H VARUN
# 5.11
# AMIT SAKRI
# 3.49
# ANURAG MAHESH JOSHI
# 7.90
# AMITHA CHOWDHARY NANDINA
# 8.13
# Error in name
# Error in sgpa
# ANIL JAYAPPA ARIKATTI
# 5.45
# MOVVA DHANUSH
# 1.28
# PAMALI SNEHA KRISHNAMURTI
# 8.92
# JAGADISH B BASAPUR
# 7.15
# ABHINANDAN GURUPRASAD HIREMATH
# 7.30
# DHARESH AMARASHETTY
# 5.54
# AKHIL VENKATESH SHANBHAG
# 8.15
# JYOTHI IRANNA MIRJE
# 4.62
# ATHARV V KADOLE
# 6.05
# PRACHI A KALAL
# 0.00
# SUSHMITA KORISHETTY
# 8.24
# ANIKET ARVIND AMBEKAR
# 3.49
# CHAITRA GIRISH HEGDE
# 7.47
# ANUSHA N TANDUR
# 6.83
# ABHISHEK ASHOK PATIL
# 8.58
# YAJAS SARATH MENON
# 7.75
# RITESH MAHESH BAGEWADI
# 1.71
# SHWETA HONNAPPANAVAR
# 4.52
# NITHYA M M
# 4.90
# AKSHATH ANAND MUGAD
# 7.30
# Error in name
# Error in sgpa
# ATHAR MUJTABA
# 7.07
# KARTHIK HIREMATH
# 8.49
# SAANJALI BELGAVI
# 2.94
# HRISHIKESH V VASTRAD
# 2.45
# ARYA MAHANTESH KINAGI
# 6.45
# ABHISHEK KUMAR
# 8.00
# SANGAMESH
# 8.07
# ARPITA G HEGDE
# 8.66
# ADITYA J GOVANAKOPPA
# 5.96
# KUSHAGRA TOMAR
# 9.15
# SUMEDH KULKARNI
# 6.75
# BAGAL APOORV SHIVAJI
# 7.28
# REEMAK DAWE
# 1.86
# Error in name
# Error in sgpa
# SHASHANK HEGDE
# 8.58
# Error in name
# Error in sgpa
# ANANT ALIAS SUDEEP SUHAS PINGULKAR
# 5.98
# SIRI K VENKATESH
# 8.37
# SPARSHA J SHETTY
# 7.94
# ROHAN KURDEKAR
# 7.75
# GURAV CHINMAY SUNIL
# 8.60
# MITHILESH YADAWAD
# 8.15
# RAKSHITA C BANDI
# 5.66
# GURUPRASAD D GHALIGI
# 6.81
# PRIYA A JADEKAR
# 7.98
# SAGAR AMBASA KABADI
# 8.92
# RITVIK S CHUNAMARI
# 1.98
# P S ADITYA
# 8.92
# GURURAJ SUDHAKAR HEGADE
# 8.69
# NEHA JAIN
# 7.92
# VIVEK PRAKASH MARAKUMBI
# 9.43
# Error in name
# Error in sgpa
# SHASHANK AGASIMANI
# 6.92
# SMITHA K VENKATESH
# 8.77
# ABHISHEK SHIVAPPA HOSAMANI
# 9.09
# SURAJ BABASO DIVATE
# 8.00
# GANESH RAVINDRA VERNEKAR
# 9.15
# SUSHMA ASHOK SHIVANGOUDAR
# 4.96
# N SOUMYA
# 8.83
# PRANALI PRABHAKAR JADHAV
# 7.30
# B M SAI PRATHIK
# 7.94
# MAYURI K M
# 8.77
# PARAG RAVISH HEGDE
# 9.09
# ATREY MAHADEV ANAGAL
# 8.39
# YASHVARDHAN MAHESH DIWAN
# 9.09
# PRANAV BASAVANT JADHAV
# 8.39
# KIRAN DEVENDRAPPA MYAGERI
# 7.28
# SAPTASAGAR SIDDHANT SHREEPAL
# 8.60
# AKSHAY JOSHI
# 8.83
# BHOOMIKA VASANT KUMTA
# 9.07
# PRERANA SHETTI
# 8.41
# BODHA KANTESH KULKARNI
# 6.64
# VINAYAK SUDHAKAR KONE
# 8.98
# RAKSHITHA R T
# 9.15
# SWAROOP RAGHAVENDRA ANEGUNDI
# 8.81
# FIZA FEROZ KHAN
# 9.52
# SHIVANI PARAPPA HALEMANI
# 8.24
# AMRUTA A AYACHIT
# 9.18
# SUPREETH S KADAPPANAVAR
# 5.77
# BHARAT A JAIN
# 9.32
# PREETI GOURE
# 8.43
# PRAJAKTA KULKARNI
# 8.77
# KARTIK MANOJI KALAL
# 8.66
# DHIRAJ RAMESH BHANDARE
# 9.00
# PRANAVI PANDURANG KULKARNI
# 7.13
# APOORVA K KASIGAVI
# 9.49
# VITTAL B HUNDARAD
# 8.83
# NIKITA
# 7.32
# SHEETAL SHANTARAM GARAD
# 6.30
# GAGANDEEP R LAMANI
# 7.75
# TRIVENI REVANASIDDAPPA KALWAD
# 8.66
# PRAVEEN ANIL DEVADKAR
# 8.66
# ROSHAN
# 5.11
# ANIKET GANESH PAI
# 9.07
# HARSHAKUMAR R HUNASHYAL
# 8.75
# T M GAGAN
# 7.98
# CHANDANA N G
# 6.00
# ABHAY P PATTAR
# 4.52
# SAHANA BASAVANTGOUDA KANTEPPAGOUDRA
# 7.32
# RAGHAVENDRA M K
# 8.07
# NEERAJ N K
# 8.83
# Error in name
# Error in sgpa
# PAVITHRA VASANADA
# 8.77
# SRISHTI ABBIGERI
# 8.24
# ANOOP PATIL
# 7.81
# SHRUTI NAGAPPA BAGODI
# 4.47
# NEEDA FATIMA ATTAR
# 8.92
# NEKKANTI SAIKEERTANA
# 6.64
# SWATI MALAGOUDA PATIL
# 8.32
# ADITYA PRAKASH NELLIKERI
# 6.81
# VISHWANATH YAMANUR BHAJANTRI
# 8.07
# SHREYAS JOSHI
# 8.98
# NEHA RAIKAR
# 8.75
# ABDUL MAJID MUJAHID
# 8.56
# ROHIT GOLABHAVI
# 5.00
# VARUN SHANKAR JAKANUR
# 7.98
# VINAYAK SIDRAMAYYANMATH
# 8.49
# KIRANKUMAR PATIL
# 7.81
# KALAVATI TALLI
# 7.92
# TEJA M CHABBI
# 7.52
# AKASH V DALAWAYI
# 8.75
# JAHNAVI HALAWAI
# 6.47
# BHIMRAO JAGADISH SHETTEPPAGOL
# 8.32
# OM VISHNUDAS PRABHU
# 9.15
# VINUTA S ARAMANI
# 9.00
# GURUTEJ R ABBIGERI
# 9.26
# ABHILASH DODDWAD
# 7.49
# VIJU RANGANNAVAR
# 8.66
# KAILASH ANGADI
# 8.32
# SWATI SADASHIV MUDAVI
# 8.49
# SANGAMESH PATIL
# 8.49
# SOHAM KAKADE
# 8.73
# PRAJWAL N SHAVI
# 8.92
# NEHA T PATIL
# 8.58
# YASH DESHPANDE
# 7.77
# OMSAI PRASAD GADGE
# 8.58
# SHANKARALING SHIVANAND HALEMANI
# 7.15
# VARUN PANDHARI
# 6.22
# TAFREEN Z HUSSIAN
# 7.24
# PAVANI PATIL
# 8.60
# SHRAVAN SANJAY NAYAK
# 7.00
# SANTOSH REDDY
# 8.49
# AVANI PATIL
# 6.47
# FAYAZ
# 6.75
# AKHILESH UTTAM GADAGKAR
# 8.75
# NAGARAJ NAIK
# 5.62
# SHREYAS SHRIKANT BHAT
# 8.18
# MANGESH DAYANAND SHANBHAG
# 8.90
# GURKIRAT SINGH
# 8.81
# RAMITA SAIRAM COMMI
# 8.98
# SANA RAZEEN G V
# 8.75
# LAVANYA SHAHAPUR
# 8.73
# SINDHU VIGHNESHWARA BHAT
# 8.60
# MADHURA K PATIL
# 8.32
# ANSHUL MISHRA
# 8.64
# PRAGATHI PUJARI
# 8.66
# NAVEEN GURUNATH BALLARI
# 6.22
# AZEEM MEHABOOB JALAGERI
# 7.56
# SOUMYA SHEKHAR GUTTIGOLI
# 9.00
# KIRAN CHANNABASAPPA NAREGAL
# 8.41
# UTKARSH KHOT
# 8.81
# ACHYUT PADAKI
# 3.60
# VAISHNAVI PATIL
# 9.32
# SHASHANK M HOSAPETI
# 6.88
# AVINASH YUVARAJ P
# 5.20
# BHARATH A KOLI
# 6.13
# SRUJAN B BASHETTI
# 8.07
# MICHAEL ROHAN SWAMINATHAN
# 9.15
# ADITI PRERNA
# 8.35
# APOORVA M ANGADI
# 8.73
# NISHANTH RAJESH NEGALI
# 9.49
# PRASANNAKUMAR BASAVARAJ ROOGI
# 5.43
# SURABHI SAINATH NAIK
# 8.15
# AAYUSHI GUPTA
# 8.66
# ASHWINI RAVIKIRAN JANNU
# 7.47
# ANUSHA A PATIL
# 6.98
# BHUVI DINESH SANGAM
# 8.32
# SUYASH M KAMAT
# 6.79
# PRIYANSH RAJ
# 8.64
# NIKHIL DHUPADAL
# 9.11
# SAMEER AHMED ANKALAGI
# 7.83
# DARSHAN U DIXIT
# 8.32
# SHREYAS SHRIDHAR JAKATI
# 8.58
# SANJANA M DYAVAPPANAVAR
# 8.66
# SHRINIDHI P ALUR
# 7.30
# ANUSHA C CHIKKAMATH
# 9.49
# SANDESH S PATILKULKARNI
# 8.32
# VISHAL VIJAYKUMAR JOSHI
# 7.49
# AMIT SANTOSH LADDIGATTI
# 8.60
# MANVANTH B S
# 8.58
# VAISHNAVI TORGAL
# 9.09
# SANJEEVINI GUNDAGATTI
# 8.66
# SRUJAN ITAGALLI
# 8.49
# SHRINIDHI R HIRERADDI
# 8.66
# VINAYAK MERAWADE
# 7.41
# SIDDARAJ S HUBBALLI
# 9.49
# ANIRUDH K
# 8.75
# SUMA DODDAMANI
# 5.83
# PRAJWAL KAILASNATH PATIL
# 9.26
# ROHIT REDDY
# 6.98
# KISHORKUMAR T
# 7.41
# NAYANA D G
# 8.41
# H KAVANASHREE
# 7.60
# PRATIBHA LAGAMANNA HALYAL
# 8.18
# TEJAS G V
# 7.86
# M PRIYA
# 8.60
# ABHAY I SHIROL
# 8.26
# DHANARAJ K
# 4.79
# HALLI HARSHITA
# 7.83
# OMKAR KAMBLE
# 5.28
# SAGAR SATISH KANAMADI
# 7.83
# ABHISHEK GIRIDHAR PAI
# 0.00
# ROHIT DEVARANAVADAGI
# 7.49
# SHASHVI SRANIK JAIN
# 8.92
# ANAGHA A BENGERI
# 8.58
# HARSHA DESAI
# 3.75
# PRATEEK KABADAR
# 8.24
# VISHAL FARANDE
# 8.41
# TANVI BHUJANNAVAR
# 7.98
# Error in name
# Error in sgpa
# RAHUL KUMAR THAKUR
# 7.39
# VAIBHAV KUMAR
# 7.56
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# SITANSHU S HALLAD
# 8.58
# Error in name
# Error in sgpa
# SATWIK KULKARNI
# 8.13
# VIVEK KUMAR
# 9.26
# Error in name
# Error in sgpa
# SIDHANT CHATURWEDI
# 2.47
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# SHUBHAM KUMAR
# 8.32
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# VIBHUTI RAJ
# 7.13
# Error in name
# Error in sgpa
# CHANDAN SRIVASTAVA B
# 8.92
# Error in name
# Error in sgpa
# CHIRAG S BIRADAR
# 4.43
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# ABHISHEK S MASUR
# 8.92
# Error in name
# Error in sgpa
# AKASH ARYAN
# 8.24
# Error in name
# Error in sgpa
# Error in name
# Error in sgpa
# GUTTI BHARATH SAI
# 7.24
# PALLAVI PRASHANT POTE
# 8.66
# SHASHANK DESAI
# 2.73
# B AJAY KUSHAL
# 8.69
# ANANTHANENI SREEVALLI CHOWDARY
# 8.00
# SRISHTI SAURAV
# 8.32
# KANUMUKKALA JASWANTH REDDY
# 7.32
# AKSHATHRAJ N BHIMAKARI
# 6.54
# RISHABH CHOUDHARY
# 4.60
# PALAK JAIN
# 7.98
# SWASTIK VINOD NAYAK
# 5.88
# BALACHENNA VAIYBHAV REDDY
# 3.58
# Error in name
# Error in sgpa
# PRIYAM KARN
# 7.22
# AKASH KUMAR
# 8.66
# NITIN KUMAR
# 7.90
# PRAKASH KUMAR SINGH
# 8.32
# RITIK KUMAR POONIA
# 8.75
# MOHIT GUMBER
# 6.88
# ANSH TIWARI
# 8.49
# ARNAV RITISH PATIL
# 2.30
# KISHANSMARAN PURANIK
# 8.18
# RAJATH V JANNU
# 7.24
# ATEETH K J
# 8.75
# ROHIT PATIL
# 8.07
# SHAKTI KUMAR SINGH
# 6.88
# NIKHIL PRAKASH PANDIT
# 8.32
# PRATEEK RENUKSWAMY BIDNURMATH
# 7.58
# PATIL SHREEVATSA SHESHAGIRI
# 5.71
# PRARTHANA ODEYAR
# 5.03
# SHOURYA
# 8.56
# ANKIT M RAICHUR
# 6.13
# ASHMIT SAXENA
# 6.88
# SHASTRANSH ROY
# 8.41
# SHIVAM SINGH
# 7.92
# SHARON GOTTIMUKKULA
# 4.18
# GANDLA HARSHITHA
# 7.75
# AMAN RAJ
# 8.43
# RISHAV PATTNAIK
# 7.90
# KARTIK PATIL
# 0.88
# KUSHAGRA PAREEK
# 7.81
# ANAND SAGAR
# 9.15
# NARENDRA VENKATA RAO THOTA
# 3.92
# PRIYANKA HUGAR
# 2.64

# %%
file.close() #closing the file
